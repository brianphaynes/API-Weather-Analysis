# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from Weather_API import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  punta arenas -53.1500  -70.9167      6.06        56          75
# 1        1  longyearbyen  78.2186   15.6401    -12.09        79          40
# 2        2        faanui -16.4833 -151.7500     27.78        74          86
# 3        3       mataura -46.1927  168.8643      5.27        84          36
# 4        4    the valley  18.2170  -63.0578     27.08        69          20
#
#    Wind Speed Country        Date
# 0        3.60      CL  1680109784
# 1        1.03      SJ  1680109785
# 2        4.23      PF  1680109785
# 3        1.77      NZ  1680109785
# 4        6.17      AI  1680109785

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Configure the map plot
map_plot_1 = city_data_df.hvplot.points("Lng","Lat", geo=True, size="Humidity", tiles= "OSM", title ="map", color="Max Temp")

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Max Temp,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
max_temp = 40
min_temp = 25
wind_speed = 15
humidity = 70
cloudiness = 10

desired_df = city_data_df[(city_data_df["Max Temp"] <= int(max_temp))&
                          (city_data_df["Max Temp"] >= int(min_temp))&
                          (city_data_df["Wind Speed"] <= int(wind_speed))&
                          (city_data_df["Humidity"] <= int(humidity))&
                          (city_data_df["Cloudiness"] <= int(cloudiness))]

# Drop any rows with null values
desired_df.dropna()

# Display sample data
desired_df
# Out:
#      City_ID                        City      Lat       Lng  Max Temp  \
# 8          8                        chuy -33.6971  -53.4616     29.11
# 10        10                     empalme  27.9667 -110.8167     25.75
# 24        24                    acapulco  16.8634  -99.8901     29.90
# 34        34                    cidreira -30.1811  -50.2056     29.57
# 113      113            diego de almagro -26.3667  -70.0500     28.26
# 121      121                       arlit  18.7369    7.3853     32.98
# 130      130             emiliano zapata  18.8333  -99.1833     28.34
# 203      203                       adrar  20.5022  -10.0711     36.60
# 219      219                       ahuas  15.4759  -84.3553     31.04
# 233      233                  tombouctou  20.0000   -3.0000     37.05
# 244      244  general jose eduvigis diaz -27.1667  -58.4167     38.17
# 253      253                   tacoronte  28.4769  -16.4102     28.18
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = desired_df.loc[:,['City','Country','Lat',"Lng","Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df
# Out:
#                            City Country      Lat       Lng  Humidity  \
# 8                          chuy      UY -33.6971  -53.4616        40
# 10                      empalme      MX  27.9667 -110.8167        27
# 24                     acapulco      MX  16.8634  -99.8901        54
# 34                     cidreira      BR -30.1811  -50.2056        60
# 113            diego de almagro      CL -26.3667  -70.0500        25
# 121                       arlit      NE  18.7369    7.3853         5
# 130             emiliano zapata      MX  18.8333  -99.1833        32
# 203                       adrar      MR  20.5022  -10.0711         5
# 219                       ahuas      HN  15.4759  -84.3553        36
# 233                  tombouctou      ML  20.0000   -3.0000         6
# 244  general jose eduvigis diaz      PY -27.1667  -58.4167        28
# 253                   tacoronte      ES  28.4769  -16.4102        13
# 281                       praya      CV  14.9215  -23.5087        21
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
#limit= 10
#radius = 10000
#categories = "accomodation.hotel"
params = {"categories": "accommodation.hotel",
          "limit": 10,
          "apiKey":geoapify_key}
   

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lon = row['Lng']
    
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    
    
    # Convert the API response to JSON format
    name_address = name_address.json()

    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# chuy - nearest hotel: Alerces
# empalme - nearest hotel: No hotel found
# acapulco - nearest hotel: Hotel del Valle
# cidreira - nearest hotel: Hotel Castelo
# diego de almagro - nearest hotel: Residencial Hambyll
# arlit - nearest hotel: No hotel found
# emiliano zapata - nearest hotel: Radisson Hotel Quinta Rubelinas Cuernavaca
# adrar - nearest hotel: No hotel found
# ahuas - nearest hotel: No hotel found
# tombouctou - nearest hotel: No hotel found
# general jose eduvigis diaz - nearest hotel: No hotel found
# tacoronte - nearest hotel: No hotel found
# praya - nearest hotel: Casa Sodadi
# black river - nearest hotel: No hotel found
# arraial do cabo - nearest hotel: No hotel found
# san miguel - nearest hotel: Continental Plaza Hotel
# oussouye - nearest hotel: Campement Alulum
# pisco - nearest hotel: La Portada
# praia - nearest hotel: Casa Sodadi
# mindelo - nearest hotel: Solar Windelo
# mahuva - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles= "OSM",
    title ="map",
    color="City",
    hover_cols = ["Hotel Name", "Country", "City"])

# Display the map
map_plot2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Country)
